# %%
import stats_utils

# %%
file_path = "im_pred_perf.xlsx"
sheet_name = "Magdeburg dataset full image"
top_left_cell = "B1148"
bottom_right_cell = "K1235"

# Available metrics:
# metrics = ['cross-correlation', 'nRMSE', 'SSIM', 'mean DVF error', 'max DVF error']
metrics = ["cross-correlation", "nRMSE", "SSIM", "mean DVF error"]

# %%
sheet_name = "Magdeburg dataset full image"
metric = "SSIM"
results = stats_utils.analyze_forecasting_methods(file_path, sheet_name, top_left_cell, bottom_right_cell, metric)
results["combined_table"]
# Out:
# Analyzing metric: SSIM
# Loading data from Magdeburg dataset full image, range B1148:K1235
# Found 10 methods with data for SSIM
# Methods: ['RTRL', 'UORO', 'SnAp1', 'DNI', 'Fixed W', 'Seq-Transformer', 'Linear prediction', 'Prev. weight', 'LMS', 'Prev. image']
#
# Summary for SSIM:
# - Methods compared: 10
# - Sequences per method: 8
# - Significant comparisons (p < 0.05): 34
#                   RTRL          UORO          SnAp1            DNI  \
# RTRL                 —  0.109 (0.65)   0.547 (0.35)   0.312 (0.72)
# UORO                 -             —  0.148 (-0.52)  0.945° (0.16)
# SnAp1                -             -              —   0.109 (0.63)
# DNI                  -             -              -              —
# Fixed W              -             -              -              -
# Seq-Transformer      -             -              -              -
# Linear prediction    -             -              -              -
# Prev. weight         -             -              -              -
# LMS                  -             -              -              -
#
#                          Fixed W Seq-Transformer Linear prediction  \
# RTRL               0.008* (2.15)   0.008* (1.05)      0.109 (0.53)
# UORO               0.008* (1.68)    0.078 (1.03)      0.312 (0.30)
# SnAp1              0.008* (2.25)   0.039* (0.95)      0.109 (0.47)
# DNI                0.008* (1.11)    0.250 (0.49)      0.312 (0.18)
# Fixed W                        —   0.547 (-0.36)     0.461 (-0.32)
# Seq-Transformer                -               —     0.742 (-0.20)
# Linear prediction              -               -                 —
# Prev. weight                   -               -                 -
# LMS                            -               -                 -
#
#                     Prev. weight             LMS    Prev. image
# RTRL               0.008* (2.45)    0.250 (0.47)  0.016* (1.73)
# UORO               0.008* (3.00)  0.844° (-0.08)  0.016* (1.75)
# SnAp1              0.008* (2.41)    0.383 (0.38)  0.016* (1.67)
# DNI                0.008* (2.34)   0.461 (-0.30)  0.016* (1.49)
# Fixed W            0.008* (2.24)   0.055 (-0.94)  0.016* (1.27)
# Seq-Transformer    0.008* (2.81)   0.195 (-0.49)  0.016* (1.54)
# Linear prediction  0.008* (2.86)   0.250 (-0.23)  0.008* (2.07)
# Prev. weight                   —  0.008* (-1.85)   0.742 (0.12)
# LMS                            -               —  0.016* (1.35)

# %%
sheet_name = "Magdeburg dataset full image"
metric = "mean DVF error"
results = stats_utils.analyze_forecasting_methods(file_path, sheet_name, top_left_cell, bottom_right_cell, metric)
results["combined_table"]
# Out:
# Analyzing metric: mean DVF error
# Loading data from Magdeburg dataset full image, range B1148:K1235
# Found 9 methods with data for mean DVF error
# Methods: ['RTRL', 'UORO', 'SnAp1', 'DNI', 'Fixed W', 'Seq-Transformer', 'Linear prediction', 'Prev. weight', 'LMS']
#
# Summary for mean DVF error:
# - Methods compared: 9
# - Sequences per method: 8
# - Significant comparisons (p < 0.05): 29
#                   RTRL            UORO          SnAp1             DNI  \
# RTRL                 —  0.008* (-1.32)  0.742 (-0.07)  0.039* (-0.90)
# UORO                 -               —  0.016* (1.19)  1.000° (-0.03)
# SnAp1                -               -              —  0.008* (-0.96)
# DNI                  -               -              -               —
# Fixed W              -               -              -               -
# Seq-Transformer      -               -              -               -
# Linear prediction    -               -              -               -
# Prev. weight         -               -              -               -
#
#                           Fixed W Seq-Transformer Linear prediction  \
# RTRL               0.008* (-1.90)  0.008* (-1.04)     0.109 (-0.47)
# UORO               0.008* (-1.55)   0.109 (-0.75)     0.383 (-0.16)
# SnAp1              0.008* (-1.75)  0.008* (-0.98)     0.148 (-0.44)
# DNI                 0.055 (-0.77)   0.195 (-0.54)     0.312 (-0.13)
# Fixed W                         —  0.641° (-0.16)      0.461 (0.23)
# Seq-Transformer                 -               —      0.383 (0.40)
# Linear prediction               -               -                 —
# Prev. weight                    -               -                 -
#
#                      Prev. weight             LMS
# RTRL               0.008* (-1.71)  0.016* (-0.95)
# UORO               0.008* (-1.66)  0.742° (-0.05)
# SnAp1              0.008* (-1.68)  0.039* (-0.91)
# DNI                0.008* (-1.50)  0.641° (-0.02)
# Fixed W            0.008* (-1.62)    0.109 (0.64)
# Seq-Transformer    0.008* (-1.95)    0.250 (0.45)
# Linear prediction  0.008* (-2.01)    0.461 (0.10)
# Prev. weight                    —   0.008* (1.43)

# %%
sheet_name = "Magdeburg dataset ROI"
metric = "mean DVF error"
results = stats_utils.analyze_forecasting_methods(file_path, sheet_name, top_left_cell, bottom_right_cell, metric)
results["combined_table"]
# Out:
# Analyzing metric: mean DVF error
# Loading data from Magdeburg dataset ROI, range B1148:K1235
# Found 9 methods with data for mean DVF error
# Methods: ['RTRL', 'UORO', 'SnAp1', 'DNI', 'Fixed W', 'Seq-Transformer', 'Linear prediction', 'Prev. weight', 'LMS']
#
# Summary for mean DVF error:
# - Methods compared: 9
# - Sequences per method: 8
# - Significant comparisons (p < 0.05): 27
#                   RTRL            UORO          SnAp1             DNI  \
# RTRL                 —  0.023* (-1.10)  0.742 (-0.20)   0.109 (-0.80)
# UORO                 -               —   0.109 (0.85)  0.945° (-0.07)
# SnAp1                -               -              —  0.039* (-0.83)
# DNI                  -               -              -               —
# Fixed W              -               -              -               -
# Seq-Transformer      -               -              -               -
# Linear prediction    -               -              -               -
# Prev. weight         -               -              -               -
#
#                           Fixed W Seq-Transformer Linear prediction  \
# RTRL               0.008* (-1.84)  0.008* (-1.38)     0.055 (-0.85)
# UORO               0.008* (-1.58)  0.016* (-1.29)     0.148 (-0.60)
# SnAp1              0.008* (-1.76)  0.008* (-1.29)     0.078 (-0.76)
# DNI                0.016* (-1.30)  0.016* (-0.98)     0.195 (-0.45)
# Fixed W                         —   0.461 (-0.37)      0.945 (0.14)
# Seq-Transformer                 -               —      0.461 (0.38)
# Linear prediction               -               -                 —
# Prev. weight                    -               -                 -
#
#                      Prev. weight             LMS
# RTRL               0.008* (-1.86)   0.055 (-0.75)
# UORO               0.008* (-1.85)  0.641° (-0.08)
# SnAp1              0.008* (-1.78)   0.055 (-0.74)
# DNI                0.008* (-1.62)  0.844° (-0.04)
# Fixed W            0.008* (-1.64)    0.078 (0.84)
# Seq-Transformer    0.008* (-1.84)    0.055 (0.78)
# Linear prediction  0.008* (-2.10)    0.383 (0.36)
# Prev. weight                    —   0.008* (1.51)

# %%
sheet_name = "Magdeburg dataset ROI"
metric = "SSIM"
results = stats_utils.analyze_forecasting_methods(file_path, sheet_name, top_left_cell, bottom_right_cell, metric)
results["combined_table"]
# Out:
# Analyzing metric: SSIM
# Loading data from Magdeburg dataset ROI, range B1148:K1235
# Found 10 methods with data for SSIM
# Methods: ['RTRL', 'UORO', 'SnAp1', 'DNI', 'Fixed W', 'Seq-Transformer', 'Linear prediction', 'Prev. weight', 'LMS', 'Prev. image']
#
# Summary for SSIM:
# - Methods compared: 10
# - Sequences per method: 8
# - Significant comparisons (p < 0.05): 34
#                   RTRL          UORO          SnAp1            DNI  \
# RTRL                 —  0.148 (0.52)   0.844 (0.20)   0.250 (0.71)
# UORO                 -             —  0.250 (-0.45)  0.844° (0.16)
# SnAp1                -             -              —   0.078 (0.62)
# DNI                  -             -              -              —
# Fixed W              -             -              -              -
# Seq-Transformer      -             -              -              -
# Linear prediction    -             -              -              -
# Prev. weight         -             -              -              -
# LMS                  -             -              -              -
#
#                          Fixed W Seq-Transformer Linear prediction  \
# RTRL               0.008* (0.82)   0.008* (1.21)      0.109 (0.66)
# UORO               0.008* (0.71)   0.016* (1.47)      0.250 (0.54)
# SnAp1              0.008* (0.81)   0.008* (1.16)      0.109 (0.64)
# DNI                0.008* (0.75)    0.078 (0.75)      0.312 (0.34)
# Fixed W                        —   0.312 (-0.42)     0.148 (-0.58)
# Seq-Transformer                -               —     0.547 (-0.23)
# Linear prediction              -               -                 —
# Prev. weight                   -               -                 -
# LMS                            -               -                 -
#
#                     Prev. weight             LMS    Prev. image
# RTRL               0.008* (2.54)    0.312 (0.45)  0.008* (1.79)
# UORO               0.008* (3.47)  0.844° (-0.08)  0.008* (2.19)
# SnAp1              0.008* (2.59)    0.383 (0.36)  0.008* (1.79)
# DNI                0.008* (2.46)   0.383 (-0.34)  0.016* (1.63)
# Fixed W             0.109 (0.88)  0.016* (-0.76)   0.148 (0.51)
# Seq-Transformer    0.008* (2.78)   0.109 (-0.72)  0.016* (1.48)
# Linear prediction  0.008* (4.11)   0.195 (-0.37)  0.008* (1.97)
# Prev. weight                   —  0.008* (-2.00)  0.078 (-0.83)
# LMS                            -               —  0.016* (1.41)
