# %%
import stats_utils

# %%
file_path = "im_pred_perf.xlsx"
sheet_name = "Magdeburg dataset full image"
top_left_cell = "B1148"
bottom_right_cell = "K1235"

# Available metrics:
# metrics = ['cross-correlation', 'nRMSE', 'SSIM', 'mean DVF error', 'max DVF error']
metrics = ["cross-correlation", "nRMSE", "SSIM", "mean DVF error"]

# For shortening sizes in Python and reordering methods in the results table to display
METHODS = {
    "RNN with UORO": "UORO",
    "RNN with SnAp1": "SnAp1",
    "RNN with DNI": "DNI",
    "RNN with RTRL": "RTRL",
    "multivariate LMS": "LMS",
    "Linear prediction": "Linear regression",
    "sequence-specific transformer": "Seq-Transformer",
    "population transformer": "Pop-Transformer",
    "RNN with fixed W": "Fixed W",
    "No prediction (lastest PCA weight)": "Prev. weight",
    "Previous image as prediction": "Prev. image",
}

# %%
sheet_name = "Magdeburg dataset full image"
metric = "SSIM"
results = stats_utils.analyze_forecasting_methods(
    file_path, sheet_name, top_left_cell, bottom_right_cell, metric, METHODS
)
results["combined_table"]
# Out:
# Analyzing metric: SSIM
# Loading data from Magdeburg dataset full image, range B1148:K1235
# Found 11 methods with data for SSIM
# Methods: ['RTRL', 'UORO', 'SnAp1', 'DNI', 'Fixed W', 'Seq-Transformer', 'Pop-Transformer', 'Linear regression', 'Prev. weight', 'LMS', 'Prev. image']
#
# Summary for SSIM:
# - Methods compared: 11
# - Sequences per method: 8
# - Significant comparisons (p < 0.05): 49
#                   UORO          SnAp1            DNI           RTRL  \
# UORO                 —  0.148 (-0.52)  0.945° (0.16)  0.109 (-0.65)
# SnAp1                -              —   0.109 (0.63)  0.547 (-0.35)
# DNI                  -              -              —  0.312 (-0.72)
# RTRL                 -              -              -              —
# LMS                  -              -              -              -
# Linear regression    -              -              -              -
# Seq-Transformer      -              -              -              -
# ...

# %%
sheet_name = "Magdeburg dataset full image"
metric = "mean DVF error"
results = stats_utils.analyze_forecasting_methods(
    file_path, sheet_name, top_left_cell, bottom_right_cell, metric, METHODS
)
results["combined_table"]
# Out:
# Analyzing metric: mean DVF error
# Loading data from Magdeburg dataset full image, range B1148:K1235
# Found 10 methods with data for mean DVF error
# Methods: ['RTRL', 'UORO', 'SnAp1', 'DNI', 'Fixed W', 'Seq-Transformer', 'Pop-Transformer', 'Linear regression', 'Prev. weight', 'LMS']
#
# Summary for mean DVF error:
# - Methods compared: 10
# - Sequences per method: 8
# - Significant comparisons (p < 0.05): 46
#                   UORO          SnAp1             DNI           RTRL  \
# UORO                 —  0.016* (1.19)  1.000° (-0.03)  0.008* (1.32)
# SnAp1                -              —  0.008* (-0.96)   0.742 (0.07)
# DNI                  -              -               —  0.039* (0.90)
# RTRL                 -              -               -              —
# LMS                  -              -               -              -
# Linear regression    -              -               -              -
# Seq-Transformer      -              -               -              -
# ...

# %%
sheet_name = "Magdeburg dataset ROI"
metric = "mean DVF error"
results = stats_utils.analyze_forecasting_methods(
    file_path, sheet_name, top_left_cell, bottom_right_cell, metric, METHODS
)
results["combined_table"]
# Out:
# Analyzing metric: mean DVF error
# Loading data from Magdeburg dataset ROI, range B1148:K1235
# Found 10 methods with data for mean DVF error
# Methods: ['RTRL', 'UORO', 'SnAp1', 'DNI', 'Fixed W', 'Seq-Transformer', 'Pop-Transformer', 'Linear regression', 'Prev. weight', 'LMS']
#
# Summary for mean DVF error:
# - Methods compared: 10
# - Sequences per method: 8
# - Significant comparisons (p < 0.05): 42
#                   UORO         SnAp1             DNI           RTRL  \
# UORO                 —  0.109 (0.85)  0.945° (-0.07)  0.023* (1.10)
# SnAp1                -             —  0.039* (-0.83)   0.742 (0.20)
# DNI                  -             -               —   0.109 (0.80)
# RTRL                 -             -               -              —
# LMS                  -             -               -              -
# Linear regression    -             -               -              -
# Seq-Transformer      -             -               -              -
# ...

# %%
sheet_name = "Magdeburg dataset ROI"
metric = "SSIM"
results = stats_utils.analyze_forecasting_methods(
    file_path, sheet_name, top_left_cell, bottom_right_cell, metric, METHODS
)
results["combined_table"]
# Out:
# Analyzing metric: SSIM
# Loading data from Magdeburg dataset ROI, range B1148:K1235
# Found 11 methods with data for SSIM
# Methods: ['RTRL', 'UORO', 'SnAp1', 'DNI', 'Fixed W', 'Seq-Transformer', 'Pop-Transformer', 'Linear regression', 'Prev. weight', 'LMS', 'Prev. image']
#
# Summary for SSIM:
# - Methods compared: 11
# - Sequences per method: 8
# - Significant comparisons (p < 0.05): 47
#                   UORO          SnAp1            DNI           RTRL  \
# UORO                 —  0.250 (-0.45)  0.844° (0.16)  0.148 (-0.52)
# SnAp1                -              —   0.078 (0.62)  0.844 (-0.20)
# DNI                  -              -              —  0.250 (-0.71)
# RTRL                 -              -              -              —
# LMS                  -              -              -              -
# Linear regression    -              -              -              -
# Seq-Transformer      -              -              -              -
# ...
